# %% [markdown]
# ## 청경채 성장 예측 AI 경진대회(데이콘)
# https://dacon.io/competitions/official/235961/

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rc('font', family='NanumGothic') 

from datetime import timedelta

import seaborn as sns

import warnings
warnings.filterwarnings(action='ignore')

import os

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic') 
import numpy as np
import pandas as pd
from tqdm import tqdm
from glob import glob
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
from sklearn.metrics import mean_absolute_error
import statsmodels.api as sm
import warnings
warnings.filterwarnings("ignore")
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import train_test_split
import cv2

# %%
path = 'train_input/'
train_inputs = os.listdir('train_input/')

for file_name in train_inputs:
    globals()[file_name.split('.')[0]+'_input'] = pd.read_csv(path+file_name)

# %%
path = 'train_target/'
train_targets = os.listdir('train_target/')

for file_name in train_targets:
    globals()[file_name.split('.')[0]+'_target'] = pd.read_csv(path+file_name)

# %%
import random
import pandas as pd
import numpy as np
import os
import glob

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from tqdm.auto import tqdm

from sklearn.preprocessing import MinMaxScaler
from sklearn import metrics

import warnings
warnings.filterwarnings(action='ignore')

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %% [markdown]
# Scale

# %%
# feature_names = ['내부온도관측치','내부습도관측치','CO2관측치', 
#                  '펌프상태', '일간누적분무량', '내부유동팬상태', '외부환기팬상태',
#                  '난방부하', '냉방부하', '총추정광량','백색광추정광량', '적색광추정광량', '청색광추정광량']
feature_names = ['외부환기팬작동남은시간', '레드 LED동작강도', '냉방부하', '내부습도관측치', '외부환기팬상태', '화이트 LED동작강도', '백색광추정광량', '총추정광량']

original_cols = ['시간', '내부온도관측치', '내부습도관측치', 'CO2관측치', 'EC관측치', '외부온도관측치', '외부습도관측치',
                 '펌프상태', '펌프작동남은시간', '최근분무량', '일간누적분무량', '냉방상태', '냉방작동남은시간',
                 '난방상태', '난방작동남은시간', '내부유동팬상태', '내부유동팬작동남은시간', '외부환기팬상태',
                 '외부환기팬작동남은시간', '화이트 LED상태', '화이트 LED작동남은시간', '화이트 LED동작강도',
                 '레드 LED상태', '레드 LED작동남은시간', '레드 LED동작강도', '블루 LED상태', '블루 LED작동남은시간',
                 '블루 LED동작강도', '카메라상태', '냉방온도', '난방온도', '기준온도', '난방부하', '냉방부하',
                 '총추정광량', '백색광추정광량', '적색광추정광량', '청색광추정광량']

# %%
# df_final = CASE_01_input

# for i in range(2,59):
#     df=eval(f'CASE_{str(i).zfill(2)}_input')
#     df.columns= original_cols
#     df_final = pd.concat([df_final,df], ignore_index=True)
    
# scaler = MinMaxScaler()
# scaler.fit(df_final.drop('시간', axis=1))

# %%
# 각 칼럼별 중앙값으로 채우기
def filling_na(df):
    #칼럼 맞추고, 스케일링 파트
#     df.columns= original_cols
#     df = df.drop('시간', axis=1)
    
    #결측치 채우기
    df_col_list = df.columns.tolist()
    df_describe = df.describe().fillna(0)
    
    for col in df_col_list:
        if col == '시간':
            continue
        else:
            df[col] = df[col].fillna(df_describe[col]['50%'])
    
    return df

# %%
def remove_outlier(df, cols):
    for col in cols:
        if col == '시간':
            continue
        else:
            outlier_idx = df[col].idxmax()
            df.loc[outlier_idx, col] = np.nan
            df[col] = df[col].fillna(method='pad')
            
            if df[col].isnull().sum() != 0:
                df[col] = df[col].fillna(0)
    return df

# %%
# 스케일링함 수
def scaling_MinMax(df):
    df = scaler.transform(df)
    df = pd.DataFrame(df, columns=original_cols[1:])
    
    return df

# %%
feature = ['내부온도관측치', '내부습도관측치', 'CO2관측치', '외부온도관측치', '외부습도관측치', '최근분무량',
            '일간누적분무량', '화이트 LED동작강도', '레드 LED동작강도', '블루 LED동작강도', '난방부하', '냉방부하',
            '총추정광량', '백색광추정광량', '적색광추정광량', '청색광추정광량','target']

# %%
eval(f'CASE_{str(1).zfill(2)}_input').columns
# original_cols
# Out:
# Index(['시간', '내부온도관측치', '내부습도관측치', 'CO2관측치', 'EC관측치', '외부온도관측치', '외부습도관측치',
#        '펌프상태', '펌프작동남은시간', '최근분무량', '일간누적분무량', '냉방상태', '냉방작동남은시간', '난방상태',
#        '난방작동남은시간', '내부유동팬상태', '내부유동팬작동남은시간', '외부환기팬상태', '외부환기팬작동남은시간',
#        '화이트 LED상태', '화이트 LED작동남은시간', '화이트 LED동작강도', '레드 LED상태', '레드 LED작동남은시간',
#        '레드 LED동작강도', '블루 LED상태', '블루 LED작동남은시간', '블루 LED동작강도', '카메라상태', '냉방온도',
#        '난방온도', '기준온도', '난방부하', '냉방부하', '총추정광량', '백색광추정광량', '적색광추정광량',
#        '청색광추정광량'],
#       dtype='object')

# %%
def groupbyday(i, test=True):
    temp = eval(f'CASE_{str(i).zfill(2)}_input')
    temp.columns = original_cols
    
    temp = filling_na(temp)
    
    temp.dropna(subset=['시간'],inplace=True)
    temp['시간'] = pd.to_datetime(temp['시간'])
    temp['년월일'] = temp['시간'].dt.year.astype(str) + '-' + temp['시간'].dt.month.astype(str) + '-' + temp['시간'].dt.day.astype(str)
    
    temp['년월일'] = pd.to_datetime(temp['년월일'])
    temp_mean = temp.groupby('년월일').mean()
    temp_mean = temp_mean.reset_index(drop=False)
    time_col = temp_mean['년월일']
    temp_mean.drop('년월일', axis=1, inplace=True)
    temp_mean['target'] = temp_mean.index
    if test:
        temp_mean['시간'] = time_col
        return temp_mean

    df = pd.DataFrame(columns=feature)
    scaler = MinMaxScaler()
    scaler.fit(temp_mean)
    df_sam = scaler.transform(temp_mean)
    df_sam = pd.DataFrame(df_sam, columns=temp_mean.columns)

    df_sam['시간']=time_col

    df = pd.concat([df, df_sam])
    return df

# %%
train = [groupbyday(i, test=False) for i in range(1,48)]
test = [groupbyday(i) for i in range(48,59)]

# %%
test[0]
# Out:
#       내부온도관측치    내부습도관측치      CO2관측치     EC관측치    외부온도관측치    외부습도관측치  \
# 0   21.107500  51.917986  546.794792  1.731846  21.532838  29.540607
# 1   21.514236  53.103715  488.920833  1.738840  22.595278  30.872153
# 2   21.795278  54.907271  485.293056  1.748795  22.441389  33.319306
# 3   22.457917  62.478375  466.813194  1.750013  23.422986  42.940275
# 4   22.788055  68.345382  474.870139  1.750594  23.858055  51.352639
# 5   22.199146  69.650004  483.341667  1.788605  21.828264  59.463622
# 6   21.438055  66.363713  500.545139  1.813837  20.133736  53.392165
# 7   21.068923  62.483906  498.867361  1.829901  20.240299  41.216624
# 24 2022-05-02
# 25 2022-05-03
# 26 2022-05-04
# 27 2022-05-05
# 28 2022-05-06
# 29 2022-05-07
# 30 2022-05-08
# 31 2022-05-09
# 32 2022-05-10
# 33 2022-05-11
# 34 2022-05-12
# 35 2022-05-13
# 36 2022-05-14
# 37 2022-05-15
# 38 2022-05-16
# 39 2022-05-17
# 40 2022-05-18
#
# [41 rows x 39 columns]

# %%
df2 = pd.DataFrame(columns=['시간','rate'])

temp = [pd.concat([df2, eval(f'CASE_{str(i).zfill(2)}_target')]) for i in range(1,59)]    
    
for df2 in temp:
    df2['시간'] = pd.to_datetime(df2['시간']) 
    df2['시간'] = df2['시간'].dt.strftime('%Y-%m-%d')
    df2['시간'] = df2['시간'].astype('str')

    
for df, df2 in zip((train + test), temp):
    df['시간'] = df['시간'].astype('str')
    df = df.merge(df2, on='시간', how='left').dropna()

# %%
for i in range(47):
    train[i] = train[i].merge(temp[i], on='시간', how='left').dropna()

for i in range(11):
    test[i] = test[i].merge(temp[47+i], on='시간', how='left').dropna()

# %%
for df in train:
    try:
        train_df = pd.concat([train_df,df])
    except:
        train_df = df
        
train_df.reset_index(drop=True, inplace=True)

# %%
for df in test:
    try:
        test_df = pd.concat([test_df,df])
    except:
        test_df = df

test_df.reset_index(drop=True, inplace=True)

# %%
import xgboost as xgb

# %%
feature = ['내부온도관측치', '내부습도관측치', 'CO2관측치', '외부온도관측치', '외부습도관측치', '최근분무량',
            '일간누적분무량', '화이트 LED동작강도', '레드 LED동작강도', '블루 LED동작강도', '난방부하', '냉방부하',
            '총추정광량', '백색광추정광량', '적색광추정광량', '청색광추정광량']
# feature = original_cols
target = 'rate'

# %%
train_df
# Out:
#        내부온도관측치   내부습도관측치    CO2관측치   외부온도관측치   외부습도관측치     최근분무량   일간누적분무량  \
# 0     0.016595  0.126161  0.135204  0.000000  0.055119  0.926623  0.930234
# 1     0.000000  0.128636  0.028126  0.069107  0.232157  0.902882  0.800004
# 2     0.468532  0.000000  0.000000  0.357312  0.547471  0.997031  0.857877
# 3     0.748370  0.329593  0.340939  0.668620  0.643601  0.917805  0.811452
# 4     0.761729  0.753206  0.377430  0.728365  0.861512  0.933065  0.894417
# ...        ...       ...       ...       ...       ...       ...       ...
# 1441  0.947870  0.773458  0.447454  0.000000  0.000000  0.400671  0.774515
# 1442  0.907855  0.837682  0.426066  0.000000  0.000000  0.382887  0.818241
# 1443  0.919003  0.776975  0.470960  0.000000  0.000000  1.000000  0.827400
# 1444  0.944637  0.948501  0.466877  0.000000  0.000000  0.000000  0.532141
# 1445  1.000000  1.000000  0.858910  0.000000  0.000000  0.196708  0.707107
#
#       화이트 LED동작강도  레드 LED동작강도  블루 LED동작강도  ...  레드 LED상태  레드 LED작동남은시간  \
# 0        1.000000    0.987779    0.380569  ...  0.200249      0.956841
# 1        0.994020    0.986323    0.380400  ...  0.000000      0.954986
# 2        0.995024    0.987066    0.380710  ...  0.350249      0.954903
# 3        0.992481    0.988308    0.380569  ...  0.450249      0.974923
# 4        0.999442    0.988369    0.382118  ...  0.300000      0.967640
# ...           ...         ...         ...  ...       ...           ...
# 1441     0.377713    0.000000    0.000000  ...  0.985366      0.713403
# 1442     0.384782    0.000000    0.000000  ...  0.964837      0.863507
# 1443     0.374470    0.000000    0.000000  ...  0.970687      0.714059
# 1444     0.376299    0.000000    0.000000  ...  0.970746      0.690336
# 1445     0.382848    0.000000    0.000000  ...  0.956038      0.888269
#
#       블루 LED상태  블루 LED작동남은시간  카메라상태      냉방온도      난방온도      기준온도          시간  \
# 0     0.105318      0.951031    1.0  0.997122  0.996803  0.009467  2021-02-18
# 1     0.000000      0.960637    1.0  0.997314  0.997017  0.009479  2021-02-19
# 2     0.262772      0.963578    0.5  0.997436  0.997153  0.009486  2021-02-20
# 3     0.368352      0.966088    0.5  0.996160  0.995735  0.009412  2021-02-21
# 4     0.315431      0.971915    0.5  0.977176  0.974649  0.008317  2021-02-22
# ...        ...           ...    ...       ...       ...       ...         ...
# 1441  0.979409      0.699526    0.0  0.356475  0.356475  0.356475  2022-04-21
# 1442  0.973451      0.854953    0.0  0.377316  0.377316  0.377316  2022-04-22
# 1443  0.973480      0.714590    1.0  0.356685  0.356685  0.356685  2022-04-23
# 1444  0.973510      0.693032    0.0  0.356468  0.356468  0.356468  2022-04-24
# 1445  0.952846      0.885586    0.0  0.381020  0.381020  0.381020  2022-04-25
#
#          rate
# 0     0.50000
# 1     0.66667
# 2     0.60000
# 3    -0.12500
# 4     1.42857
# ...       ...
# 1441  0.22476
# 1442  0.21755
# 1443  0.23329
# 1444  0.11123
# 1445  0.06376
#
# [1446 rows x 40 columns]

# %%
# feature = train_df.columns[:-2]
# target = train_df.columns[-1]

# %%
X_train = train_df[feature]
y_train = train_df[target]

X_test = test_df[feature]
y_test = test_df[target]

# %%
reg = xgb.XGBRegressor(n_estimators=400, early_stopping_rounds=50,
                      learning_rate=1e-3)
reg.fit(X_train,y_train,
        eval_set = [(X_train,y_train),(X_test, y_test)],
       verbose=True)
# Out:
# [14:27:43] WARNING: /tmp/xgboost/src/learner.cc:547:
# Parameters: { early_stopping_rounds } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	validation_0-rmse:1.65169	validation_1-rmse:1.17972
# [1]	validation_0-rmse:1.65087	validation_1-rmse:1.17968
# [2]	validation_0-rmse:1.65004	validation_1-rmse:1.17963
# [3]	validation_0-rmse:1.64922	validation_1-rmse:1.17959
# [4]	validation_0-rmse:1.64839	validation_1-rmse:1.17955
# [5]	validation_0-rmse:1.64757	validation_1-rmse:1.17951
# [6]	validation_0-rmse:1.64675	validation_1-rmse:1.17947
# [7]	validation_0-rmse:1.64593	validation_1-rmse:1.17942
# [8]	validation_0-rmse:1.64511	validation_1-rmse:1.17938
# [9]	validation_0-rmse:1.64428	validation_1-rmse:1.17934
# [10]	validation_0-rmse:1.64346	validation_1-rmse:1.17930
# [11]	validation_0-rmse:1.64264	validation_1-rmse:1.17926
# [12]	validation_0-rmse:1.64183	validation_1-rmse:1.17922
# [13]	validation_0-rmse:1.64101	validation_1-rmse:1.17918
# [14]	validation_0-rmse:1.64019	validation_1-rmse:1.17914
# [15]	validation_0-rmse:1.63937	validation_1-rmse:1.17910
# [16]	validation_0-rmse:1.63855	validation_1-rmse:1.17905
# [17]	validation_0-rmse:1.63773	validation_1-rmse:1.17901
# [18]	validation_0-rmse:1.63692	validation_1-rmse:1.17897
# [19]	validation_0-rmse:1.63610	validation_1-rmse:1.17893
# [20]	validation_0-rmse:1.63529	validation_1-rmse:1.17889
# [21]	validation_0-rmse:1.63447	validation_1-rmse:1.17885
# [22]	validation_0-rmse:1.63366	validation_1-rmse:1.17881
# [23]	validation_0-rmse:1.63284	validation_1-rmse:1.17877
# [24]	validation_0-rmse:1.63203	validation_1-rmse:1.17873
# [25]	validation_0-rmse:1.63121	validation_1-rmse:1.17869
# [26]	validation_0-rmse:1.63040	validation_1-rmse:1.17866
# [27]	validation_0-rmse:1.62959	validation_1-rmse:1.17862
# [28]	validation_0-rmse:1.62878	validation_1-rmse:1.17858
# [29]	validation_0-rmse:1.62797	validation_1-rmse:1.17854
# [30]	validation_0-rmse:1.62715	validation_1-rmse:1.17850
# [31]	validation_0-rmse:1.62634	validation_1-rmse:1.17846
# [32]	validation_0-rmse:1.62553	validation_1-rmse:1.17842
# [33]	validation_0-rmse:1.62472	validation_1-rmse:1.17838
# [34]	validation_0-rmse:1.62391	validation_1-rmse:1.17834
# [35]	validation_0-rmse:1.62310	validation_1-rmse:1.17831
# [36]	validation_0-rmse:1.62230	validation_1-rmse:1.17827
# [37]	validation_0-rmse:1.62149	validation_1-rmse:1.17823
# [38]	validation_0-rmse:1.62068	validation_1-rmse:1.17819
# [39]	validation_0-rmse:1.61987	validation_1-rmse:1.17816
# [40]	validation_0-rmse:1.61907	validation_1-rmse:1.17812
# [41]	validation_0-rmse:1.61826	validation_1-rmse:1.17808
# [42]	validation_0-rmse:1.61745	validation_1-rmse:1.17804
# [43]	validation_0-rmse:1.61665	validation_1-rmse:1.17800
# [44]	validation_0-rmse:1.61584	validation_1-rmse:1.17797
# [45]	validation_0-rmse:1.61504	validation_1-rmse:1.17793
# [46]	validation_0-rmse:1.61424	validation_1-rmse:1.17789
# [47]	validation_0-rmse:1.61343	validation_1-rmse:1.17786
# [48]	validation_0-rmse:1.61263	validation_1-rmse:1.17782
# [49]	validation_0-rmse:1.61183	validation_1-rmse:1.17779
# [50]	validation_0-rmse:1.61102	validation_1-rmse:1.17775
# [51]	validation_0-rmse:1.61022	validation_1-rmse:1.17771
# [52]	validation_0-rmse:1.60942	validation_1-rmse:1.17768
# [53]	validation_0-rmse:1.60862	validation_1-rmse:1.17764
# [54]	validation_0-rmse:1.60782	validation_1-rmse:1.17760
# [55]	validation_0-rmse:1.60702	validation_1-rmse:1.17757
# [56]	validation_0-rmse:1.60622	validation_1-rmse:1.17753
# [57]	validation_0-rmse:1.60542	validation_1-rmse:1.17750
# [58]	validation_0-rmse:1.60462	validation_1-rmse:1.17746
# [59]	validation_0-rmse:1.60382	validation_1-rmse:1.17743
# [60]	validation_0-rmse:1.60303	validation_1-rmse:1.17739
# [61]	validation_0-rmse:1.60223	validation_1-rmse:1.17736
# [62]	validation_0-rmse:1.60143	validation_1-rmse:1.17732
# [63]	validation_0-rmse:1.60064	validation_1-rmse:1.17729
# [64]	validation_0-rmse:1.59984	validation_1-rmse:1.17725
# [65]	validation_0-rmse:1.59904	validation_1-rmse:1.17722
# [66]	validation_0-rmse:1.59825	validation_1-rmse:1.17718
# [67]	validation_0-rmse:1.59745	validation_1-rmse:1.17715
# [68]	validation_0-rmse:1.59666	validation_1-rmse:1.17711
# [69]	validation_0-rmse:1.59587	validation_1-rmse:1.17708
# [70]	validation_0-rmse:1.59507	validation_1-rmse:1.17705
# [71]	validation_0-rmse:1.59428	validation_1-rmse:1.17701
# [72]	validation_0-rmse:1.59349	validation_1-rmse:1.17698
# [73]	validation_0-rmse:1.59270	validation_1-rmse:1.17694
# [74]	validation_0-rmse:1.59190	validation_1-rmse:1.17691
# [75]	validation_0-rmse:1.59111	validation_1-rmse:1.17688
# [76]	validation_0-rmse:1.59032	validation_1-rmse:1.17684
# [77]	validation_0-rmse:1.58953	validation_1-rmse:1.17681
# [78]	validation_0-rmse:1.58874	validation_1-rmse:1.17678
# [79]	validation_0-rmse:1.58795	validation_1-rmse:1.17675
# [80]	validation_0-rmse:1.58716	validation_1-rmse:1.17671
# [81]	validation_0-rmse:1.58638	validation_1-rmse:1.17668
# [82]	validation_0-rmse:1.58559	validation_1-rmse:1.17665
# [83]	validation_0-rmse:1.58480	validation_1-rmse:1.17661
# [84]	validation_0-rmse:1.58401	validation_1-rmse:1.17658
# [85]	validation_0-rmse:1.58323	validation_1-rmse:1.17655
# [86]	validation_0-rmse:1.58244	validation_1-rmse:1.17652
# [87]	validation_0-rmse:1.58165	validation_1-rmse:1.17649
# [88]	validation_0-rmse:1.58087	validation_1-rmse:1.17646
# [89]	validation_0-rmse:1.58008	validation_1-rmse:1.17642
# [90]	validation_0-rmse:1.57930	validation_1-rmse:1.17639
# [91]	validation_0-rmse:1.57851	validation_1-rmse:1.17636
# [92]	validation_0-rmse:1.57773	validation_1-rmse:1.17633
# [93]	validation_0-rmse:1.57695	validation_1-rmse:1.17630
# [94]	validation_0-rmse:1.57617	validation_1-rmse:1.17627
# [95]	validation_0-rmse:1.57538	validation_1-rmse:1.17623
# [96]	validation_0-rmse:1.57460	validation_1-rmse:1.17620
# [97]	validation_0-rmse:1.57382	validation_1-rmse:1.17617
# [98]	validation_0-rmse:1.57304	validation_1-rmse:1.17614
# [99]	validation_0-rmse:1.57226	validation_1-rmse:1.17611
# [100]	validation_0-rmse:1.57148	validation_1-rmse:1.17608
# [101]	validation_0-rmse:1.57070	validation_1-rmse:1.17605
# [102]	validation_0-rmse:1.56992	validation_1-rmse:1.17602
# [103]	validation_0-rmse:1.56914	validation_1-rmse:1.17599
# [241]	validation_0-rmse:1.46569	validation_1-rmse:1.17303
# [242]	validation_0-rmse:1.46497	validation_1-rmse:1.17301
# [243]	validation_0-rmse:1.46425	validation_1-rmse:1.17300
# [244]	validation_0-rmse:1.46353	validation_1-rmse:1.17298
# [245]	validation_0-rmse:1.46281	validation_1-rmse:1.17297
# [246]	validation_0-rmse:1.46209	validation_1-rmse:1.17296
# [247]	validation_0-rmse:1.46137	validation_1-rmse:1.17294
# [248]	validation_0-rmse:1.46065	validation_1-rmse:1.17293
# [249]	validation_0-rmse:1.45993	validation_1-rmse:1.17292
# [250]	validation_0-rmse:1.45921	validation_1-rmse:1.17290
# [251]	validation_0-rmse:1.45850	validation_1-rmse:1.17289
# [252]	validation_0-rmse:1.45778	validation_1-rmse:1.17287
# [253]	validation_0-rmse:1.45706	validation_1-rmse:1.17286
# [254]	validation_0-rmse:1.45635	validation_1-rmse:1.17285
# [255]	validation_0-rmse:1.45563	validation_1-rmse:1.17283
# [256]	validation_0-rmse:1.45491	validation_1-rmse:1.17282
# [257]	validation_0-rmse:1.45420	validation_1-rmse:1.17281
# [258]	validation_0-rmse:1.45348	validation_1-rmse:1.17279
# [259]	validation_0-rmse:1.45277	validation_1-rmse:1.17278
# [260]	validation_0-rmse:1.45206	validation_1-rmse:1.17276
# [261]	validation_0-rmse:1.45134	validation_1-rmse:1.17275
# [262]	validation_0-rmse:1.45063	validation_1-rmse:1.17273
# [263]	validation_0-rmse:1.44991	validation_1-rmse:1.17272
# [264]	validation_0-rmse:1.44920	validation_1-rmse:1.17270
# [265]	validation_0-rmse:1.44849	validation_1-rmse:1.17269
# [266]	validation_0-rmse:1.44777	validation_1-rmse:1.17268
# [267]	validation_0-rmse:1.44706	validation_1-rmse:1.17267
# [268]	validation_0-rmse:1.44635	validation_1-rmse:1.17266
# [269]	validation_0-rmse:1.44564	validation_1-rmse:1.17264
# [270]	validation_0-rmse:1.44493	validation_1-rmse:1.17263
# [271]	validation_0-rmse:1.44422	validation_1-rmse:1.17262
# [272]	validation_0-rmse:1.44351	validation_1-rmse:1.17261
# [273]	validation_0-rmse:1.44280	validation_1-rmse:1.17259
# [274]	validation_0-rmse:1.44209	validation_1-rmse:1.17258
# [275]	validation_0-rmse:1.44138	validation_1-rmse:1.17257
# [276]	validation_0-rmse:1.44067	validation_1-rmse:1.17256
# [277]	validation_0-rmse:1.43996	validation_1-rmse:1.17254
# [278]	validation_0-rmse:1.43925	validation_1-rmse:1.17253
# [279]	validation_0-rmse:1.43854	validation_1-rmse:1.17252
# [280]	validation_0-rmse:1.43784	validation_1-rmse:1.17250
# [281]	validation_0-rmse:1.43713	validation_1-rmse:1.17249
# [282]	validation_0-rmse:1.43643	validation_1-rmse:1.17248
# [283]	validation_0-rmse:1.43572	validation_1-rmse:1.17246
# [284]	validation_0-rmse:1.43501	validation_1-rmse:1.17246
# [285]	validation_0-rmse:1.43431	validation_1-rmse:1.17244
# [286]	validation_0-rmse:1.43360	validation_1-rmse:1.17243
# [287]	validation_0-rmse:1.43290	validation_1-rmse:1.17242
# [288]	validation_0-rmse:1.43219	validation_1-rmse:1.17240
# [289]	validation_0-rmse:1.43149	validation_1-rmse:1.17239
# [290]	validation_0-rmse:1.43079	validation_1-rmse:1.17238
# [291]	validation_0-rmse:1.43009	validation_1-rmse:1.17237
# [292]	validation_0-rmse:1.42938	validation_1-rmse:1.17236
# [293]	validation_0-rmse:1.42868	validation_1-rmse:1.17235
# [294]	validation_0-rmse:1.42798	validation_1-rmse:1.17233
# [295]	validation_0-rmse:1.42728	validation_1-rmse:1.17232
# [296]	validation_0-rmse:1.42657	validation_1-rmse:1.17231
# [297]	validation_0-rmse:1.42587	validation_1-rmse:1.17230
# [298]	validation_0-rmse:1.42517	validation_1-rmse:1.17229
# [299]	validation_0-rmse:1.42447	validation_1-rmse:1.17228
# [300]	validation_0-rmse:1.42378	validation_1-rmse:1.17226
# [301]	validation_0-rmse:1.42308	validation_1-rmse:1.17225
# [302]	validation_0-rmse:1.42238	validation_1-rmse:1.17224
# [303]	validation_0-rmse:1.42168	validation_1-rmse:1.17223
# [304]	validation_0-rmse:1.42098	validation_1-rmse:1.17222
# [305]	validation_0-rmse:1.42028	validation_1-rmse:1.17221
# [306]	validation_0-rmse:1.41959	validation_1-rmse:1.17219
# [307]	validation_0-rmse:1.41889	validation_1-rmse:1.17218
# [308]	validation_0-rmse:1.41819	validation_1-rmse:1.17217
# [309]	validation_0-rmse:1.41750	validation_1-rmse:1.17216
# [310]	validation_0-rmse:1.41680	validation_1-rmse:1.17215
# [311]	validation_0-rmse:1.41611	validation_1-rmse:1.17214
# [312]	validation_0-rmse:1.41541	validation_1-rmse:1.17213
# [313]	validation_0-rmse:1.41472	validation_1-rmse:1.17212
# [314]	validation_0-rmse:1.41402	validation_1-rmse:1.17210
# [315]	validation_0-rmse:1.41333	validation_1-rmse:1.17209
# [316]	validation_0-rmse:1.41264	validation_1-rmse:1.17209
# [317]	validation_0-rmse:1.41194	validation_1-rmse:1.17207
# [318]	validation_0-rmse:1.41125	validation_1-rmse:1.17206
# [319]	validation_0-rmse:1.41056	validation_1-rmse:1.17206
# [320]	validation_0-rmse:1.40986	validation_1-rmse:1.17204
# [321]	validation_0-rmse:1.40918	validation_1-rmse:1.17203
# [322]	validation_0-rmse:1.40848	validation_1-rmse:1.17203
# [323]	validation_0-rmse:1.40779	validation_1-rmse:1.17201
# [324]	validation_0-rmse:1.40710	validation_1-rmse:1.17200
# [325]	validation_0-rmse:1.40641	validation_1-rmse:1.17199
# [326]	validation_0-rmse:1.40572	validation_1-rmse:1.17198
# [327]	validation_0-rmse:1.40503	validation_1-rmse:1.17197
# [328]	validation_0-rmse:1.40434	validation_1-rmse:1.17196
# [329]	validation_0-rmse:1.40366	validation_1-rmse:1.17195
# [330]	validation_0-rmse:1.40297	validation_1-rmse:1.17194
# [331]	validation_0-rmse:1.40228	validation_1-rmse:1.17193
# [332]	validation_0-rmse:1.40159	validation_1-rmse:1.17192
# [333]	validation_0-rmse:1.40091	validation_1-rmse:1.17191
# [334]	validation_0-rmse:1.40022	validation_1-rmse:1.17190
# [335]	validation_0-rmse:1.39953	validation_1-rmse:1.17190
# [336]	validation_0-rmse:1.39885	validation_1-rmse:1.17189
# [337]	validation_0-rmse:1.39816	validation_1-rmse:1.17188
# [338]	validation_0-rmse:1.39748	validation_1-rmse:1.17187
# [339]	validation_0-rmse:1.39679	validation_1-rmse:1.17186
# [340]	validation_0-rmse:1.39611	validation_1-rmse:1.17185
# [341]	validation_0-rmse:1.39542	validation_1-rmse:1.17184
# [342]	validation_0-rmse:1.39474	validation_1-rmse:1.17183
# [343]	validation_0-rmse:1.39406	validation_1-rmse:1.17182
# [344]	validation_0-rmse:1.39338	validation_1-rmse:1.17181
# [345]	validation_0-rmse:1.39269	validation_1-rmse:1.17180
# [346]	validation_0-rmse:1.39201	validation_1-rmse:1.17179
# [347]	validation_0-rmse:1.39133	validation_1-rmse:1.17178
# [348]	validation_0-rmse:1.39065	validation_1-rmse:1.17177
# [349]	validation_0-rmse:1.38997	validation_1-rmse:1.17176
# [350]	validation_0-rmse:1.38929	validation_1-rmse:1.17175
# [351]	validation_0-rmse:1.38861	validation_1-rmse:1.17174
# [352]	validation_0-rmse:1.38793	validation_1-rmse:1.17173
# [353]	validation_0-rmse:1.38725	validation_1-rmse:1.17172
# [354]	validation_0-rmse:1.38657	validation_1-rmse:1.17171
# [355]	validation_0-rmse:1.38590	validation_1-rmse:1.17170
# [356]	validation_0-rmse:1.38522	validation_1-rmse:1.17169
# [357]	validation_0-rmse:1.38454	validation_1-rmse:1.17168
# [358]	validation_0-rmse:1.38387	validation_1-rmse:1.17168
# [359]	validation_0-rmse:1.38319	validation_1-rmse:1.17167
# [360]	validation_0-rmse:1.38251	validation_1-rmse:1.17166
# [361]	validation_0-rmse:1.38184	validation_1-rmse:1.17165
# [362]	validation_0-rmse:1.38116	validation_1-rmse:1.17163
# [363]	validation_0-rmse:1.38049	validation_1-rmse:1.17163
# [364]	validation_0-rmse:1.37981	validation_1-rmse:1.17162
# [365]	validation_0-rmse:1.37914	validation_1-rmse:1.17161
# [366]	validation_0-rmse:1.37847	validation_1-rmse:1.17160
# [367]	validation_0-rmse:1.37779	validation_1-rmse:1.17159
# [368]	validation_0-rmse:1.37712	validation_1-rmse:1.17158
# [369]	validation_0-rmse:1.37645	validation_1-rmse:1.17157
# [370]	validation_0-rmse:1.37577	validation_1-rmse:1.17157
# [371]	validation_0-rmse:1.37510	validation_1-rmse:1.17156
# [372]	validation_0-rmse:1.37443	validation_1-rmse:1.17155
# [373]	validation_0-rmse:1.37376	validation_1-rmse:1.17154
# [374]	validation_0-rmse:1.37309	validation_1-rmse:1.17153
# [375]	validation_0-rmse:1.37242	validation_1-rmse:1.17152
# [376]	validation_0-rmse:1.37175	validation_1-rmse:1.17151
# [377]	validation_0-rmse:1.37108	validation_1-rmse:1.17151
# [378]	validation_0-rmse:1.37041	validation_1-rmse:1.17150
# [379]	validation_0-rmse:1.36974	validation_1-rmse:1.17149
# [380]	validation_0-rmse:1.36907	validation_1-rmse:1.17148
# [381]	validation_0-rmse:1.36840	validation_1-rmse:1.17147
# [382]	validation_0-rmse:1.36774	validation_1-rmse:1.17146
# [383]	validation_0-rmse:1.36707	validation_1-rmse:1.17145
# [384]	validation_0-rmse:1.36640	validation_1-rmse:1.17144
# [385]	validation_0-rmse:1.36573	validation_1-rmse:1.17144
# [386]	validation_0-rmse:1.36507	validation_1-rmse:1.17143
# [387]	validation_0-rmse:1.36440	validation_1-rmse:1.17142
# [388]	validation_0-rmse:1.36374	validation_1-rmse:1.17141
# [389]	validation_0-rmse:1.36307	validation_1-rmse:1.17140
# [390]	validation_0-rmse:1.36241	validation_1-rmse:1.17140
# [391]	validation_0-rmse:1.36174	validation_1-rmse:1.17139
# [392]	validation_0-rmse:1.36108	validation_1-rmse:1.17138
# [393]	validation_0-rmse:1.36041	validation_1-rmse:1.17137
# [394]	validation_0-rmse:1.35975	validation_1-rmse:1.17136
# [395]	validation_0-rmse:1.35909	validation_1-rmse:1.17136
# [396]	validation_0-rmse:1.35842	validation_1-rmse:1.17135
# [397]	validation_0-rmse:1.35776	validation_1-rmse:1.17134
# [398]	validation_0-rmse:1.35710	validation_1-rmse:1.17134
# [399]	validation_0-rmse:1.35644	validation_1-rmse:1.17133
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, early_stopping_rounds=50,
#              gamma=0, gpu_id=-1, importance_type='gain',
#              interaction_constraints='', learning_rate=0.001, max_delta_step=0,
#              max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=400, n_jobs=4,
#              num_parallel_tree=1, random_state=0, reg_alpha=0, reg_lambda=1,
#              scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
X_train
# Out:
#        내부온도관측치   내부습도관측치    CO2관측치   외부온도관측치   외부습도관측치     최근분무량   일간누적분무량  \
# 0     0.016595  0.126161  0.135204  0.000000  0.055119  0.926623  0.930234
# 1     0.000000  0.128636  0.028126  0.069107  0.232157  0.902882  0.800004
# 2     0.468532  0.000000  0.000000  0.357312  0.547471  0.997031  0.857877
# 3     0.748370  0.329593  0.340939  0.668620  0.643601  0.917805  0.811452
# 4     0.761729  0.753206  0.377430  0.728365  0.861512  0.933065  0.894417
# ...        ...       ...       ...       ...       ...       ...       ...
# 1441  0.947870  0.773458  0.447454  0.000000  0.000000  0.400671  0.774515
# 1442  0.907855  0.837682  0.426066  0.000000  0.000000  0.382887  0.818241
# 1443  0.919003  0.776975  0.470960  0.000000  0.000000  1.000000  0.827400
# 1444  0.944637  0.948501  0.466877  0.000000  0.000000  0.000000  0.532141
# 1445  1.000000  1.000000  0.858910  0.000000  0.000000  0.196708  0.707107
#
#       화이트 LED동작강도  레드 LED동작강도  블루 LED동작강도      난방부하      냉방부하     총추정광량  \
# 0        1.000000    0.987779    0.380569  0.030215  0.000000  0.000000
# 1        0.994020    0.986323    0.380400  0.453228  0.047523  0.000000
# 2        0.995024    0.987066    0.380710  0.000000  0.326087  0.000000
# 3        0.992481    0.988308    0.380569  0.000000  0.653653  0.000000
# 4        0.999442    0.988369    0.382118  0.000000  0.670115  0.000000
# ...           ...         ...         ...       ...       ...       ...
# 1441     0.377713    0.000000    0.000000  0.221385  0.661398  0.376861
# 1442     0.384782    0.000000    0.000000  0.547780  0.387063  0.384033
# 1443     0.374470    0.000000    0.000000  0.483408  0.479090  0.374470
# 1444     0.376299    0.000000    0.000000  0.214677  0.644499  0.375260
# 1445     0.382848    0.000000    0.000000  0.000000  1.000000  0.381881
#
#        백색광추정광량  적색광추정광량  청색광추정광량
# 0     0.000000      0.0      0.0
# 1     0.000000      0.0      0.0
# 2     0.000000      0.0      0.0
# 3     0.000000      0.0      0.0
# 4     0.000000      0.0      0.0
# ...        ...      ...      ...
# 1441  0.376861      0.0      0.0
# 1442  0.384033      0.0      0.0
# 1443  0.374470      0.0      0.0
# 1444  0.375260      0.0      0.0
# 1445  0.381881      0.0      0.0
#
# [1446 rows x 16 columns]

# %%
reg.feature_importances_
# Out:
# array([8.5922167e-02, 4.6951461e-01, 1.7851943e-02, 3.3144222e-04,
#        3.2350373e-01, 1.1319907e-03, 5.3623933e-03, 1.0397693e-03,
#        7.1674382e-04, 3.0426981e-03, 7.1729661e-04, 6.1968365e-04,
#        8.4222219e-04, 2.1919252e-03, 2.9172394e-02, 5.8038969e-02],
#       dtype=float32)

# %%
pd.DataFrame(reg.feature_importances_, index = feature, columns=['importance']).sort_values(by='importance', ascending=False)
# Out:
#              importance
# 내부습도관측치        0.469515
# 외부습도관측치        0.323504
# 내부온도관측치        0.085922
# 청색광추정광량        0.058039
# 적색광추정광량        0.029172
# CO2관측치         0.017852
# 일간누적분무량        0.005362
# 블루 LED동작강도     0.003043
# 백색광추정광량        0.002192
# 최근분무량          0.001132
# 화이트 LED동작강도    0.001040
# 총추정광량          0.000842
# 난방부하           0.000717
# 레드 LED동작강도     0.000717
# 냉방부하           0.000620
# 외부온도관측치        0.000331

# %%
def avg_day(temp):
    temp.dropna(subset=['시간'],inplace=True)
    temp['시간'] = pd.to_datetime(temp['시간'])
    temp['년월일'] = temp['시간'].dt.year.astype(str) + '-' + temp['시간'].dt.month.astype(str) + '-' + temp['시간'].dt.day.astype(str)
    
    temp['년월일'] = pd.to_datetime(temp['년월일'])
    temp = temp.groupby('년월일').mean()
    return temp

# %%
test_input = [pd.read_csv(f'./test_input/TEST_{str(num+1).zfill(2)}.csv') for num in range(6)]

# %%
test_target = [pd.read_csv(f'./test_target/TEST_{str(num+1).zfill(2)}.csv') for num in range(6)]

# %%
for i in range(6):
    df = avg_day(test_input[i])
    df['rate'] = reg.predict(df[feature])
    test_input[i] = df

# %%
for i in range(6):
    if test_target[i].shape[0] == test_input[i].shape[0]:
        test_target[i].rate = list(test_input[i].rate)
    else:
        dif = test_input[i].shape[0] - test_target[i].shape[0]
        test_target[i].rate = list(test_input[i][dif:].rate)

# %%
import glob
test_target_list = sorted(glob.glob('./test_target/*.csv'))

# %%
import zipfile
os.chdir("./test_target/")
submission = zipfile.ZipFile("../submission_0825.zip", 'w')
for path in test_target_list:
    path = path.split('/')[-1]
    submission.write(path)
submission.close()
os.chdir("..")
